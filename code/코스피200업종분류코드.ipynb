# %% [markdown]
# ### 필요한 라이브러리

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
from collections import defaultdict
import csv
import re

# %% [markdown]
# ### COSPI 200 편입 종목 크롤링

# %%
BaseUrl = 'http://finance.naver.com/sise/entryJongmok.nhn?&page='

# 종목 코드 추출
stock_codes = []

for i in range(1, 21):  # range() 함수의 끝 파라미터는 포함되지 않는다.
    url = BaseUrl + str(i)
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'lxml')
    items = soup.find_all('td', {'class': 'ctg'})
    for item in items:
        txt = item.a.get('href')  # 예: https://finance.naver.com/item/main.nhn?code=006390
        k = re.search('[\d]+', txt)  # 정규표현식 사용. [\d] 숫자표현, + : 반복
        if k:
            code = k.group()
            stock_codes.append(code)

print(stock_codes)
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\d'
# <>:13: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/vw/vspwd_yn6b94yd37dg899j380000gn/T/ipykernel_73063/155905241.py:13: SyntaxWarning: invalid escape sequence '\d'
#   k = re.search('[\d]+', txt)  # 정규표현식 사용. [\d] 숫자표현, + : 반복
# ['005930', '000660', '373220', '207940', '005380', '012450', '068270', '000270', '329180', '105560', '035420', '055550', '012330', '042660', '138040', '005490', '028260', '009540', '034020', '086790', '259960', '000810', '032830', '035720', '010130', '015760', '011200', '051910', '096770', '033780', '316140', '030200', '010140', '064350', '024110', '006400', '402340', '066570', '017670', '352820', '267260', '323410', '003550', '018260', '003670', '034730', '000100', '009150', '047050', '086280', '326030', '047810', '003490', '272210', '042700', '003230', '090430', '079550', '006800', '010620', '005830', '021240', '267250', '010120', '010950', '180640', '051900', '032640', '009830', '161390', '005940', '000150', '271560', '029780', '241560', '016360', '000720', '071050', '298040', '377300', '034220', '006260', '450080', '011790', '251270', '028050', '022100', '001040', '000880', '097950', '078930', '036460', '035250', '128940', '039490', '175330', '011070', '138930', '004020', '454910', '036570', '011780', '302440', '489790', '017800', '278470', '383220', '052690', '026960', '011170', '139480', '004370', '018880', '012750', '004990', '066970', '088350', '081660', '002380', '001440', '030000', '111770', '008930', '001450', '051600', '192820', '023530', '000120', '282330', '002790', '161890', '028670', '204320', '008770', '139130', '375500', '103140', '112610', '007310', '361610', '069620', '042670', '006360', '005850', '004170', '047040', '006280', '009420', '000240', '073240', '000080', '069960', '014680', '009970', '457190', '005070', '300720', '007070', '010060', '192080', '003090', '011210', '001800', '137310', '185750', '280360', '001120', '298020', '005300', '336260', '009240', '004490', '014820', '003030', '001740', '002840', '004000', '003240', '039130', '120110', '001680', '145720', '298050', '114090', '008730', '285130', '000210', '005250', '069260', '001430', '003620', '005420', '006650', '002710', '456040', '271940', '178920', '093370', '105630', '006110']

# %% [markdown]
# ### 편입 종목을 같은 업종코드(산업군)끼리 분류 후 클러스터로 묶음

# %%
# 헤더 설정
headers = {"User-Agent": "Mozilla/5.0"}

# 종목코드로 업종코드를 추출하는 함수
def get_upjong_code_by_stock(stock_code):
    url = f"https://finance.naver.com/item/main.naver?code={stock_code}"
    try:
        res = requests.get(url, headers=headers)
        soup = BeautifulSoup(res.text, "html.parser")
        upjong_link = soup.find("a", href=lambda href: href and "sise_group_detail.naver?type=upjong" in href)
        if upjong_link:
            href = upjong_link["href"]
            upjong_code = href.split("no=")[-1]
            return upjong_code
    except Exception as e:
        print(f"[오류] {stock_code} 처리 중 예외 발생: {e}")
    return None

# 종목코드로 종목명을 가져오는 함수
def get_stock_name_from_code(stock_code):
    url = f"https://finance.naver.com/item/main.naver?code={stock_code}"
    try:
        res = requests.get(url, headers=headers)
        soup = BeautifulSoup(res.text, "html.parser")
        name = soup.select_one('div.wrap_company h2 a').text.strip()
        return name
    except:
        return None

# 업종코드별 종목 저장
upjong_groups = defaultdict(list)
stock_code_to_name = {}

for i, code in enumerate(stock_codes):
    name = get_stock_name_from_code(code)
    upjong_code = get_upjong_code_by_stock(code)
    if name:
        stock_code_to_name[code] = name
    if upjong_code:
        upjong_groups[upjong_code].append(code)
        print(f"[{i+1}/{len(stock_codes)}] {code}({name}) → 업종코드 {upjong_code}")
    else:
        print(f"[{i+1}/{len(stock_codes)}] {code}({name}) → 업종코드 없음")
    time.sleep(0.3)

# 업종코드별로 Cluster ID 부여
upjong_to_cluster = {upjong: idx for idx, upjong in enumerate(upjong_groups.keys())}

# 결과 정리
result = []
for upjong_code, codes in upjong_groups.items():
    cluster_id = upjong_to_cluster[upjong_code]
    for code in codes:
        result.append({
            "종목명": stock_code_to_name.get(code, code),
            "업종코드": upjong_code,
            "Cluster": cluster_id
        })

# 데이터프레임으로 변환
df = pd.DataFrame(result)
print("\n📦 최종 결과:")
print(df)
# Out:
# [1/200] 005930(삼성전자) → 업종코드 278
# [2/200] 000660(SK하이닉스) → 업종코드 278
# [3/200] 373220(LG에너지솔루션) → 업종코드 283
# [4/200] 207940(삼성바이오로직스) → 업종코드 261
# [5/200] 005380(현대차) → 업종코드 273
# [6/200] 012450(한화에어로스페이스) → 업종코드 284
# [7/200] 068270(셀트리온) → 업종코드 261
# [8/200] 000270(기아) → 업종코드 273
# [9/200] 329180(HD현대중공업) → 업종코드 291
# [10/200] 105560(KB금융) → 업종코드 301
# [11/200] 035420(NAVER) → 업종코드 300
# [12/200] 055550(신한지주) → 업종코드 301
# [13/200] 012330(현대모비스) → 업종코드 270
# [14/200] 042660(한화오션) → 업종코드 291
# [15/200] 138040(메리츠금융지주) → 업종코드 321
# [16/200] 005490(POSCO홀딩스) → 업종코드 304
# [17/200] 028260(삼성물산) → 업종코드 276
# [18/200] 009540(HD한국조선해양) → 업종코드 291
# [19/200] 034020(두산에너빌리티) → 업종코드 299
# [20/200] 086790(하나금융지주) → 업종코드 301
# [21/200] 259960(크래프톤) → 업종코드 263
# [22/200] 000810(삼성화재) → 업종코드 315
# [23/200] 032830(삼성생명) → 업종코드 330
# [24/200] 035720(카카오) → 업종코드 300
# [25/200] 010130(고려아연) → 업종코드 322
# [26/200] 015760(한국전력) → 업종코드 325
# [27/200] 011200(HMM) → 업종코드 323
# [28/200] 051910(LG화학) → 업종코드 272
# [29/200] 096770(SK이노베이션) → 업종코드 313
# [30/200] 033780(KT&G) → 업종코드 275
# [31/200] 316140(우리금융지주) → 업종코드 301
# [32/200] 030200(KT) → 업종코드 336
# [33/200] 010140(삼성중공업) → 업종코드 291
# [34/200] 064350(현대로템) → 업종코드 299
# [35/200] 024110(기업은행) → 업종코드 301
# [36/200] 006400(삼성SDI) → 업종코드 283
# [37/200] 402340(SK스퀘어) → 업종코드 276
# [38/200] 066570(LG전자) → 업종코드 307
# [39/200] 017670(SK텔레콤) → 업종코드 333
# [40/200] 352820(하이브) → 업종코드 285
# [41/200] 267260(HD현대일렉트릭) → 업종코드 306
# [42/200] 323410(카카오뱅크) → 업종코드 301
# [43/200] 003550(LG) → 업종코드 276
# [44/200] 018260(삼성에스디에스) → 업종코드 267
# [45/200] 003670(포스코퓨처엠) → 업종코드 272
# [46/200] 034730(SK) → 업종코드 313
# [47/200] 000100(유한양행) → 업종코드 261
# [48/200] 009150(삼성전기) → 업종코드 282
# [49/200] 047050(포스코인터내셔널) → 업종코드 334
# [50/200] 086280(현대글로비스) → 업종코드 326
# [51/200] 326030(SK바이오팜) → 업종코드 261
# [52/200] 047810(한국항공우주) → 업종코드 284
# [53/200] 003490(대한항공) → 업종코드 305
# [54/200] 272210(한화시스템) → 업종코드 284
# [55/200] 042700(한미반도체) → 업종코드 278
# [56/200] 003230(삼양식품) → 업종코드 268
# [57/200] 090430(아모레퍼시픽) → 업종코드 266
# [58/200] 079550(LIG넥스원) → 업종코드 284
# [59/200] 006800(미래에셋증권) → 업종코드 321
# [60/200] 010620(HD현대미포) → 업종코드 291
# [61/200] 005830(DB손해보험) → 업종코드 315
# [62/200] 021240(코웨이) → 업종코드 298
# [63/200] 267250(HD현대) → 업종코드 313
# [64/200] 010120(LS ELECTRIC) → 업종코드 306
# [65/200] 010950(S-Oil) → 업종코드 313
# [66/200] 180640(한진칼) → 업종코드 305
# [67/200] 051900(LG생활건강) → 업종코드 266
# [68/200] 032640(LG유플러스) → 업종코드 333
# [69/200] 009830(한화솔루션) → 업종코드 295
# [70/200] 161390(한국타이어앤테크놀로지) → 업종코드 270
# [71/200] 005940(NH투자증권) → 업종코드 321
# [72/200] 000150(두산) → 업종코드 276
# [73/200] 271560(오리온) → 업종코드 268
# [74/200] 029780(삼성카드) → 업종코드 337
# [75/200] 241560(두산밥캣) → 업종코드 299
# [76/200] 016360(삼성증권) → 업종코드 321
# [77/200] 000720(현대건설) → 업종코드 279
# [78/200] 071050(한국금융지주) → 업종코드 321
# [79/200] 298040(효성중공업) → 업종코드 306
# [80/200] 377300(카카오페이) → 업종코드 267
# [81/200] 034220(LG디스플레이) → 업종코드 327
# [82/200] 006260(LS) → 업종코드 306
# [83/200] 450080(에코프로머티) → 업종코드 283
# [84/200] 011790(SKC) → 업종코드 272
# [85/200] 251270(넷마블) → 업종코드 263
# [86/200] 028050(삼성E&A) → 업종코드 279
# [87/200] 022100(포스코DX) → 업종코드 267
# [88/200] 001040(CJ) → 업종코드 276
# [89/200] 000880(한화) → 업종코드 276
# [90/200] 097950(CJ제일제당) → 업종코드 268
# [91/200] 078930(GS) → 업종코드 313
# [92/200] 036460(한국가스공사) → 업종코드 312
# [93/200] 035250(강원랜드) → 업종코드 317
# [94/200] 128940(한미약품) → 업종코드 261
# [95/200] 039490(키움증권) → 업종코드 321
# [96/200] 175330(JB금융지주) → 업종코드 301
# [97/200] 011070(LG이노텍) → 업종코드 282
# [98/200] 138930(BNK금융지주) → 업종코드 301
# [99/200] 004020(현대제철) → 업종코드 304
# [100/200] 454910(두산로보틱스) → 업종코드 299
# [101/200] 036570(엔씨소프트) → 업종코드 263
# [102/200] 011780(금호석유화학) → 업종코드 272
# [103/200] 302440(SK바이오사이언스) → 업종코드 261
# [104/200] 489790(한화비전) → 업종코드 284
# [105/200] 017800(현대엘리베이터) → 업종코드 299
# [106/200] 278470(에이피알) → 업종코드 266
# [107/200] 383220(F&F) → 업종코드 274
# [108/200] 052690(한전기술) → 업종코드 325
# [109/200] 026960(동서) → 업종코드 268
# [110/200] 011170(롯데케미칼) → 업종코드 272
# [111/200] 139480(이마트) → 업종코드 264
# [112/200] 004370(농심) → 업종코드 268
# [113/200] 018880(한온시스템) → 업종코드 270
# [114/200] 012750(에스원) → 업종코드 324
# [115/200] 004990(롯데지주) → 업종코드 276
# [116/200] 066970(엘앤에프) → 업종코드 283
# [117/200] 088350(한화생명) → 업종코드 330
# [118/200] 081660(미스토홀딩스) → 업종코드 274
# [119/200] 002380(KCC) → 업종코드 289
# [120/200] 001440(대한전선) → 업종코드 306
# [121/200] 030000(제일기획) → 업종코드 310
# [122/200] 111770(영원무역) → 업종코드 274
# [123/200] 008930(한미사이언스) → 업종코드 261
# [124/200] 001450(현대해상) → 업종코드 315
# [125/200] 051600(한전KPS) → 업종코드 325
# [126/200] 192820(코스맥스) → 업종코드 266
# [127/200] 023530(롯데쇼핑) → 업종코드 264
# [128/200] 000120(CJ대한통운) → 업종코드 326
# [129/200] 282330(BGF리테일) → 업종코드 264
# [130/200] 002790(아모레퍼시픽홀딩스) → 업종코드 266
# [131/200] 161890(한국콜마) → 업종코드 266
# [132/200] 028670(팬오션) → 업종코드 323
# [133/200] 204320(HL만도) → 업종코드 270
# [134/200] 008770(호텔신라) → 업종코드 264
# [135/200] 139130(iM금융지주) → 업종코드 301
# [136/200] 375500(DL이앤씨) → 업종코드 279
# [137/200] 103140(풍산) → 업종코드 322
# [138/200] 112610(씨에스윈드) → 업종코드 295
# [139/200] 007310(오뚜기) → 업종코드 268
# [140/200] 361610(SK아이이테크놀로지) → 업종코드 283
# [141/200] 069620(대웅제약) → 업종코드 261
# [142/200] 042670(HD현대인프라코어) → 업종코드 299
# [143/200] 006360(GS건설) → 업종코드 279
# [144/200] 005850(에스엘) → 업종코드 270
# [145/200] 004170(신세계) → 업종코드 264
# [146/200] 047040(대우건설) → 업종코드 279
# [147/200] 006280(녹십자) → 업종코드 261
# [148/200] 009420(한올바이오파마) → 업종코드 261
# [149/200] 000240(한국앤컴퍼니) → 업종코드 270
# [150/200] 073240(금호타이어) → 업종코드 270
# [151/200] 000080(하이트진로) → 업종코드 309
# [152/200] 069960(현대백화점) → 업종코드 264
# [153/200] 014680(한솔케미칼) → 업종코드 272
# [154/200] 009970(영원무역홀딩스) → 업종코드 274
# [155/200] 457190(이수스페셜티케미컬) → 업종코드 272
# [156/200] 005070(코스모신소재) → 업종코드 272
# [157/200] 300720(한일시멘트) → 업종코드 289
# [158/200] 007070(GS리테일) → 업종코드 264
# [159/200] 010060(OCI홀딩스) → 업종코드 272
# [160/200] 192080(더블유게임즈) → 업종코드 263
# [161/200] 003090(대웅) → 업종코드 261
# [162/200] 011210(현대위아) → 업종코드 270
# [163/200] 001800(오리온홀딩스) → 업종코드 268
# [164/200] 137310(에스디바이오센서) → 업종코드 281
# [165/200] 185750(종근당) → 업종코드 261
# [166/200] 280360(롯데웰푸드) → 업종코드 268
# [167/200] 001120(LX인터내셔널) → 업종코드 334
# [168/200] 298020(효성티앤씨) → 업종코드 274
# [169/200] 005300(롯데칠성) → 업종코드 309
# [170/200] 336260(두산퓨얼셀) → 업종코드 283
# [171/200] 009240(한샘) → 업종코드 303
# [172/200] 004490(세방전지) → 업종코드 270
# [173/200] 014820(동원시스템즈) → 업종코드 311
# [174/200] 003030(세아제강지주) → 업종코드 304
# [175/200] 001740(SK네트웍스) → 업종코드 276
# [176/200] 002840(미원상사) → 업종코드 272
# [177/200] 004000(롯데정밀화학) → 업종코드 272
# [178/200] 003240(태광산업) → 업종코드 272
# [179/200] 039130(하나투어) → 업종코드 317
# [180/200] 120110(코오롱인더) → 업종코드 272
# [181/200] 001680(대상) → 업종코드 268
# [182/200] 145720(덴티움) → 업종코드 281
# [183/200] 298050(HS효성첨단소재) → 업종코드 272
# [184/200] 114090(GKL) → 업종코드 317
# [185/200] 008730(율촌화학) → 업종코드 311
# [186/200] 285130(SK케미칼) → 업종코드 272
# [187/200] 000210(DL) → 업종코드 272
# [188/200] 005250(녹십자홀딩스) → 업종코드 261
# [189/200] 069260(TKG휴켐스) → 업종코드 272
# [190/200] 001430(세아베스틸지주) → 업종코드 304
# [191/200] 003620(KG모빌리티) → 업종코드 273
# [192/200] 005420(코스모화학) → 업종코드 272
# [193/200] 006650(대한유화) → 업종코드 272
# [194/200] 002710(TCC스틸) → 업종코드 304
# [195/200] 456040(OCI) → 업종코드 272
# [196/200] 271940(일진하이솔루스) → 업종코드 270
# [197/200] 178920(PI첨단소재) → 업종코드 272
# [198/200] 093370(후성) → 업종코드 272
# [199/200] 105630(한세실업) → 업종코드 274
# [200/200] 006110(삼아알미늄) → 업종코드 322
#
# 📦 최종 결과:
#           종목명 업종코드  Cluster
# 0        삼성전자  278        0
# 1      SK하이닉스  278        0
# 2       한미반도체  278        0
# 3    LG에너지솔루션  283        1
# 4       삼성SDI  283        1
# ..        ...  ...      ...
# 195  에스디바이오센서  281       47
# 196       덴티움  281       47
# 197        한샘  303       48
# 198    동원시스템즈  311       49
# 199      율촌화학  311       49
#
# [200 rows x 3 columns]

# %%
# 클러스터 개수와 종목 확인
df
# Out:
#           종목명 업종코드  Cluster
# 0        삼성전자  278        0
# 1      SK하이닉스  278        0
# 2       한미반도체  278        0
# 3    LG에너지솔루션  283        1
# 4       삼성SDI  283        1
# ..        ...  ...      ...
# 195  에스디바이오센서  281       47
# 196       덴티움  281       47
# 197        한샘  303       48
# 198    동원시스템즈  311       49
# 199      율촌화학  311       49
#
# [200 rows x 3 columns]

# %% [markdown]
# ### CSV로 저장

# %%
# 종목코드 앞에 0이오면 0이 사라진 후 저장되는 문제가 발생
# 그 이유는 종목코드를 int로 인지했기 때문. 그래서 문자열로 바꿔줌
# 000660 같은 경우, 660으로 저장되었었음

df.to_csv("종목_업종_클러스터.csv", index=False)

# %% [markdown]
# ### 각 기업의 재무제표 데이터 합치기

# %%
df_cluster = pd.read_csv("/Users/sungsupark/Desktop/2025-1 수업자료/소프트웨어융합캡스톤디자인/code/종목_업종_클러스터_test.csv")
df_group = pd.read_csv("/Users/sungsupark/Desktop/2025-1 수업자료/소프트웨어융합캡스톤디자인/code/financial_data_processing_cospi200_test.csv")

# 병합 수행
df_merged = pd.merge(df_cluster, df_group, left_on='종목명', right_on='기업명_그룹', how='left')

# 병합용 열 제거
df_merged = df_merged.drop(columns=['기업명_그룹'])

# df_merged.to_csv("병합된_데이터프레임.csv", index=False)
# # 결과 확인
# tools.display_dataframe_to_user(name="병합된 데이터프레임", dataframe=df_merged)

# %% [markdown]
# ### 각 클러스터 평가

# %% [markdown]
# ### 두산로보틱스를 먼저 드랍해야함

# %%
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.preprocessing import StandardScaler

# 평가에 사용할 수치형 열만 선택 (Cluster 제외)
numeric_cols = df_merged.select_dtypes(include='number').columns.drop('Cluster')

# 1. 정규화 (스케일링)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_merged[numeric_cols])

# 2. 클러스터 라벨
labels = df_merged['Cluster']

# 3. 평가지표 계산
sil_score = silhouette_score(X_scaled, labels)
ch_score = calinski_harabasz_score(X_scaled, labels)
db_score = davies_bouldin_score(X_scaled, labels)

# 4. 결과 출력
print(f"✅ Silhouette Score: {sil_score:.4f}")
print(f"✅ Calinski-Harabasz Index: {ch_score:.4f}")
print(f"✅ Davies-Bouldin Index: {db_score:.4f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 15
#      12 labels = df_merged['Cluster']
#      14 # 3. 평가지표 계산
# ---> 15 sil_score = silhouette_score(X_scaled, labels)
#      16 ch_score = calinski_harabasz_score(X_scaled, labels)
#      17 db_score = davies_bouldin_score(X_scaled, labels)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/cluster/_unsupervised.py:139, in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#     137     else:
#     138         X, labels = X[indices], labels[indices]
# --> 139 return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:189, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     187 global_skip_validation = get_config()["skip_parameter_validation"]
#     188 if global_skip_validation:
# --> 189     return func(*args, **kwargs)
#     191 func_sig = signature(func)
#     193 # Map *args/**kwargs to the function signature
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/cluster/_unsupervised.py:277, in silhouette_samples(X, labels, metric, **kwds)
#     196 @validate_params(
#     197     {
#     198         "X": ["array-like", "sparse matrix"],
#    (...)
#     203 )
#     204 def silhouette_samples(X, labels, *, metric="euclidean", **kwds):
#     205     """Compute the Silhouette Coefficient for each sample.
#     206
#     207     The Silhouette Coefficient is a measure of how well samples are clustered
#    (...)
#     275     array([...])
#     276     """
# --> 277     X, labels = check_X_y(X, labels, accept_sparse=["csr"])
#     279     # Check for non-zero diagonal entries in precomputed distance matrix
#     280     if metric == "precomputed":
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:1370, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1364     raise ValueError(
#    1365         f"{estimator_name} requires y to be passed, but the target y is None"
#    1366     )
#    1368 ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
# -> 1370 X = check_array(
#    1371     X,
#    1372     accept_sparse=accept_sparse,
#    1373     accept_large_sparse=accept_large_sparse,
#    1374     dtype=dtype,
#    1375     order=order,
#    1376     copy=copy,
#    1377     force_writeable=force_writeable,
#    1378     ensure_all_finite=ensure_all_finite,
#    1379     ensure_2d=ensure_2d,
#    1380     allow_nd=allow_nd,
#    1381     ensure_min_samples=ensure_min_samples,
#    1382     ensure_min_features=ensure_min_features,
#    1383     estimator=estimator,
#    1384     input_name="X",
#    1385 )
#    1387 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1389 check_consistent_length(X, y)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:1107, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1101     raise ValueError(
#    1102         "Found array with dim %d. %s expected <= 2."
#    1103         % (array.ndim, estimator_name)
#    1104     )
#    1106 if ensure_all_finite:
# -> 1107     _assert_all_finite(
#    1108         array,
#    1109         input_name=input_name,
#    1110         estimator_name=estimator_name,
#    1111         allow_nan=ensure_all_finite == "allow-nan",
#    1112     )
#    1114 if copy:
#    1115     if _is_numpy_namespace(xp):
#    1116         # only make a copy if `array` and `array_orig` may share memory`
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:120, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     117 if first_pass_isfinite:
#     118     return
# --> 120 _assert_all_finite_element_wise(
#     121     X,
#     122     xp=xp,
#     123     allow_nan=allow_nan,
#     124     msg_dtype=msg_dtype,
#     125     estimator_name=estimator_name,
#     126     input_name=input_name,
#     127 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:169, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     152 if estimator_name and input_name == "X" and has_nan_error:
#     153     # Improve the error message on how to handle missing values in
#     154     # scikit-learn.
#     155     msg_err += (
#     156         f"\n{estimator_name} does not accept missing values"
#     157         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     167         "#estimators-that-handle-nan-values"
#     168     )
# --> 169 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
