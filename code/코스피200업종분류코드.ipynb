# %% [markdown]
# ### 필요한 라이브러리

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
from collections import defaultdict
import csv

# %% [markdown]
# ### COSPI 200 편입 종목 크롤링

# %%
BaseUrl = 'http://finance.naver.com/sise/entryJongmok.nhn?&page='

# 종목 코드 추출
stock_codes = []

for i in range(1, 21):  # range() 함수의 끝 파라미터는 포함되지 않는다.
    url = BaseUrl + str(i)
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'lxml')
    items = soup.find_all('td', {'class': 'ctg'})
    for item in items:
        txt = item.a.get('href')  # 예: https://finance.naver.com/item/main.nhn?code=006390
        k = re.search('[\d]+', txt)  # 정규표현식 사용. [\d] 숫자표현, + : 반복
        if k:
            code = k.group()
            stock_codes.append(code)

print(stock_codes)
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\d'
# <>:13: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/vw/vspwd_yn6b94yd37dg899j380000gn/T/ipykernel_18957/155905241.py:13: SyntaxWarning: invalid escape sequence '\d'
#   k = re.search('[\d]+', txt)  # 정규표현식 사용. [\d] 숫자표현, + : 반복
# ['005930', '000660', '373220', '207940', '005380', '012450', '068270', '000270', '329180', '105560', '035420', '055550', '012330', '042660', '138040', '005490', '028260', '009540', '034020', '086790', '259960', '000810', '032830', '035720', '010130', '015760', '011200', '051910', '096770', '033780', '316140', '030200', '010140', '064350', '024110', '006400', '402340', '066570', '017670', '352820', '267260', '323410', '003550', '018260', '003670', '034730', '000100', '009150', '047050', '086280', '326030', '047810', '003490', '272210', '042700', '003230', '090430', '079550', '006800', '010620', '005830', '021240', '267250', '010120', '010950', '180640', '051900', '032640', '009830', '161390', '005940', '000150', '271560', '029780', '241560', '016360', '000720', '071050', '298040', '377300', '034220', '006260', '450080', '011790', '251270', '028050', '022100', '001040', '000880', '097950', '078930', '036460', '035250', '128940', '039490', '175330', '011070', '138930', '004020', '454910', '036570', '011780', '302440', '489790', '017800', '278470', '383220', '052690', '026960', '011170', '139480', '004370', '018880', '012750', '004990', '066970', '088350', '081660', '002380', '001440', '030000', '111770', '008930', '001450', '051600', '192820', '023530', '000120', '282330', '002790', '161890', '028670', '204320', '008770', '139130', '375500', '103140', '112610', '007310', '361610', '069620', '042670', '006360', '005850', '004170', '047040', '006280', '009420', '000240', '073240', '000080', '069960', '014680', '009970', '457190', '005070', '300720', '007070', '010060', '192080', '003090', '011210', '001800', '137310', '185750', '280360', '001120', '298020', '005300', '336260', '009240', '004490', '014820', '003030', '001740', '002840', '004000', '003240', '039130', '120110', '001680', '145720', '298050', '114090', '008730', '285130', '000210', '005250', '069260', '001430', '003620', '005420', '006650', '002710', '456040', '271940', '178920', '093370', '105630', '006110']

# %% [markdown]
# ### 편입 종목을 같은 업종코드(산업군)끼리 분류 후 클러스터로 묶음

# %%
# 헤더 설정
headers = {"User-Agent": "Mozilla/5.0"}

# 업종코드를 추출하는 함수
def get_upjong_code_by_stock(stock_code):
    url = f"https://finance.naver.com/item/main.naver?code={stock_code}"
    try:
        res = requests.get(url, headers=headers)
        soup = BeautifulSoup(res.text, "html.parser")
        upjong_link = soup.find("a", href=lambda href: href and "sise_group_detail.naver?type=upjong" in href)
        if upjong_link:
            href = upjong_link["href"]
            upjong_code = href.split("no=")[-1]
            return upjong_code
    except Exception as e:
        print(f"[오류] {stock_code} 처리 중 예외 발생: {e}")
    return None

# 업종코드별 종목코드 모으기
upjong_groups = defaultdict(list)

for i, code in enumerate(stock_codes):
    upjong_code = get_upjong_code_by_stock(code)
    if upjong_code:
        upjong_groups[upjong_code].append(code)
        print(f"[{i+1}/{len(stock_codes)}] 종목 {code} → 업종코드 {upjong_code}")
    else:
        print(f"[{i+1}/{len(stock_codes)}] 종목 {code} → 업종코드 없음")
    time.sleep(0.3)

# 업종코드별로 '클러스터 ID'를 부여함
upjong_to_cluster = {upjong: idx for idx, upjong in enumerate(upjong_groups.keys())}

# 결과를 리스트로 변환함
result = []
for upjong_code, codes in upjong_groups.items():
    cluster_id = upjong_to_cluster[upjong_code]
    for code in codes:
        result.append({
            "종목코드": code,
            "업종코드": upjong_code,
            "Cluster": cluster_id
        })

# 데이터프레임으로 보기 좋게 출력함
df = pd.DataFrame(result)
print("\n📦 최종 결과:")
print(df)
# Out:
# [1/200] 종목 005930 → 업종코드 278
# [2/200] 종목 000660 → 업종코드 278
# [3/200] 종목 373220 → 업종코드 283
# [4/200] 종목 207940 → 업종코드 261
# [5/200] 종목 005380 → 업종코드 273
# [6/200] 종목 012450 → 업종코드 284
# [7/200] 종목 068270 → 업종코드 261
# [8/200] 종목 000270 → 업종코드 273
# [9/200] 종목 329180 → 업종코드 291
# [10/200] 종목 105560 → 업종코드 301
# [11/200] 종목 035420 → 업종코드 300
# [12/200] 종목 055550 → 업종코드 301
# [13/200] 종목 012330 → 업종코드 270
# [14/200] 종목 042660 → 업종코드 291
# [15/200] 종목 138040 → 업종코드 321
# [16/200] 종목 005490 → 업종코드 304
# [17/200] 종목 028260 → 업종코드 276
# [18/200] 종목 009540 → 업종코드 291
# [19/200] 종목 034020 → 업종코드 299
# [20/200] 종목 086790 → 업종코드 301
# [21/200] 종목 259960 → 업종코드 263
# [22/200] 종목 000810 → 업종코드 315
# [23/200] 종목 032830 → 업종코드 330
# [24/200] 종목 035720 → 업종코드 300
# [25/200] 종목 010130 → 업종코드 322
# [26/200] 종목 015760 → 업종코드 325
# [27/200] 종목 011200 → 업종코드 323
# [28/200] 종목 051910 → 업종코드 272
# [29/200] 종목 096770 → 업종코드 313
# [30/200] 종목 033780 → 업종코드 275
# [31/200] 종목 316140 → 업종코드 301
# [32/200] 종목 030200 → 업종코드 336
# [33/200] 종목 010140 → 업종코드 291
# [34/200] 종목 064350 → 업종코드 299
# [35/200] 종목 024110 → 업종코드 301
# [36/200] 종목 006400 → 업종코드 283
# [37/200] 종목 402340 → 업종코드 276
# [38/200] 종목 066570 → 업종코드 307
# [39/200] 종목 017670 → 업종코드 333
# [40/200] 종목 352820 → 업종코드 285
# [41/200] 종목 267260 → 업종코드 306
# [42/200] 종목 323410 → 업종코드 301
# [43/200] 종목 003550 → 업종코드 276
# [44/200] 종목 018260 → 업종코드 267
# [45/200] 종목 003670 → 업종코드 272
# [46/200] 종목 034730 → 업종코드 313
# [47/200] 종목 000100 → 업종코드 261
# [48/200] 종목 009150 → 업종코드 282
# [49/200] 종목 047050 → 업종코드 334
# [50/200] 종목 086280 → 업종코드 326
# [51/200] 종목 326030 → 업종코드 261
# [52/200] 종목 047810 → 업종코드 284
# [53/200] 종목 003490 → 업종코드 305
# [54/200] 종목 272210 → 업종코드 284
# [55/200] 종목 042700 → 업종코드 278
# [56/200] 종목 003230 → 업종코드 268
# [57/200] 종목 090430 → 업종코드 266
# [58/200] 종목 079550 → 업종코드 284
# [59/200] 종목 006800 → 업종코드 321
# [60/200] 종목 010620 → 업종코드 291
# [61/200] 종목 005830 → 업종코드 315
# [62/200] 종목 021240 → 업종코드 298
# [63/200] 종목 267250 → 업종코드 313
# [64/200] 종목 010120 → 업종코드 306
# [65/200] 종목 010950 → 업종코드 313
# [66/200] 종목 180640 → 업종코드 305
# [67/200] 종목 051900 → 업종코드 266
# [68/200] 종목 032640 → 업종코드 333
# [69/200] 종목 009830 → 업종코드 295
# [70/200] 종목 161390 → 업종코드 270
# [71/200] 종목 005940 → 업종코드 321
# [72/200] 종목 000150 → 업종코드 276
# [73/200] 종목 271560 → 업종코드 268
# [74/200] 종목 029780 → 업종코드 337
# [75/200] 종목 241560 → 업종코드 299
# [76/200] 종목 016360 → 업종코드 321
# [77/200] 종목 000720 → 업종코드 279
# [78/200] 종목 071050 → 업종코드 321
# [79/200] 종목 298040 → 업종코드 306
# [80/200] 종목 377300 → 업종코드 267
# [81/200] 종목 034220 → 업종코드 327
# [82/200] 종목 006260 → 업종코드 306
# [83/200] 종목 450080 → 업종코드 283
# [84/200] 종목 011790 → 업종코드 272
# [85/200] 종목 251270 → 업종코드 263
# [86/200] 종목 028050 → 업종코드 279
# [87/200] 종목 022100 → 업종코드 267
# [88/200] 종목 001040 → 업종코드 276
# [89/200] 종목 000880 → 업종코드 276
# [90/200] 종목 097950 → 업종코드 268
# [91/200] 종목 078930 → 업종코드 313
# [92/200] 종목 036460 → 업종코드 312
# [93/200] 종목 035250 → 업종코드 317
# [94/200] 종목 128940 → 업종코드 261
# [95/200] 종목 039490 → 업종코드 321
# [96/200] 종목 175330 → 업종코드 301
# [97/200] 종목 011070 → 업종코드 282
# [98/200] 종목 138930 → 업종코드 301
# [99/200] 종목 004020 → 업종코드 304
# [100/200] 종목 454910 → 업종코드 299
# [101/200] 종목 036570 → 업종코드 263
# [102/200] 종목 011780 → 업종코드 272
# [103/200] 종목 302440 → 업종코드 261
# [104/200] 종목 489790 → 업종코드 284
# [105/200] 종목 017800 → 업종코드 299
# [106/200] 종목 278470 → 업종코드 266
# [107/200] 종목 383220 → 업종코드 274
# [108/200] 종목 052690 → 업종코드 325
# [109/200] 종목 026960 → 업종코드 268
# [110/200] 종목 011170 → 업종코드 272
# [111/200] 종목 139480 → 업종코드 264
# [112/200] 종목 004370 → 업종코드 268
# [113/200] 종목 018880 → 업종코드 270
# [114/200] 종목 012750 → 업종코드 324
# [115/200] 종목 004990 → 업종코드 276
# [116/200] 종목 066970 → 업종코드 283
# [117/200] 종목 088350 → 업종코드 330
# [118/200] 종목 081660 → 업종코드 274
# [119/200] 종목 002380 → 업종코드 289
# [120/200] 종목 001440 → 업종코드 306
# [121/200] 종목 030000 → 업종코드 310
# [122/200] 종목 111770 → 업종코드 274
# [123/200] 종목 008930 → 업종코드 261
# [124/200] 종목 001450 → 업종코드 315
# [125/200] 종목 051600 → 업종코드 325
# [126/200] 종목 192820 → 업종코드 266
# [127/200] 종목 023530 → 업종코드 264
# [128/200] 종목 000120 → 업종코드 326
# [129/200] 종목 282330 → 업종코드 264
# [130/200] 종목 002790 → 업종코드 266
# [131/200] 종목 161890 → 업종코드 266
# [132/200] 종목 028670 → 업종코드 323
# [133/200] 종목 204320 → 업종코드 270
# [134/200] 종목 008770 → 업종코드 264
# [135/200] 종목 139130 → 업종코드 301
# [136/200] 종목 375500 → 업종코드 279
# [137/200] 종목 103140 → 업종코드 322
# [138/200] 종목 112610 → 업종코드 295
# [139/200] 종목 007310 → 업종코드 268
# [140/200] 종목 361610 → 업종코드 283
# [141/200] 종목 069620 → 업종코드 261
# [142/200] 종목 042670 → 업종코드 299
# [143/200] 종목 006360 → 업종코드 279
# [144/200] 종목 005850 → 업종코드 270
# [145/200] 종목 004170 → 업종코드 264
# [146/200] 종목 047040 → 업종코드 279
# [147/200] 종목 006280 → 업종코드 261
# [148/200] 종목 009420 → 업종코드 261
# [149/200] 종목 000240 → 업종코드 270
# [150/200] 종목 073240 → 업종코드 270
# [151/200] 종목 000080 → 업종코드 309
# [152/200] 종목 069960 → 업종코드 264
# [153/200] 종목 014680 → 업종코드 272
# [154/200] 종목 009970 → 업종코드 274
# [155/200] 종목 457190 → 업종코드 272
# [156/200] 종목 005070 → 업종코드 272
# [157/200] 종목 300720 → 업종코드 289
# [158/200] 종목 007070 → 업종코드 264
# [159/200] 종목 010060 → 업종코드 272
# [160/200] 종목 192080 → 업종코드 263
# [161/200] 종목 003090 → 업종코드 261
# [162/200] 종목 011210 → 업종코드 270
# [163/200] 종목 001800 → 업종코드 268
# [164/200] 종목 137310 → 업종코드 281
# [165/200] 종목 185750 → 업종코드 261
# [166/200] 종목 280360 → 업종코드 268
# [167/200] 종목 001120 → 업종코드 334
# [168/200] 종목 298020 → 업종코드 274
# [169/200] 종목 005300 → 업종코드 309
# [170/200] 종목 336260 → 업종코드 283
# [171/200] 종목 009240 → 업종코드 303
# [172/200] 종목 004490 → 업종코드 270
# [173/200] 종목 014820 → 업종코드 311
# [174/200] 종목 003030 → 업종코드 304
# [175/200] 종목 001740 → 업종코드 276
# [176/200] 종목 002840 → 업종코드 272
# [177/200] 종목 004000 → 업종코드 272
# [178/200] 종목 003240 → 업종코드 272
# [179/200] 종목 039130 → 업종코드 317
# [180/200] 종목 120110 → 업종코드 272
# [181/200] 종목 001680 → 업종코드 268
# [182/200] 종목 145720 → 업종코드 281
# [183/200] 종목 298050 → 업종코드 272
# [184/200] 종목 114090 → 업종코드 317
# [185/200] 종목 008730 → 업종코드 311
# [186/200] 종목 285130 → 업종코드 272
# [187/200] 종목 000210 → 업종코드 272
# [188/200] 종목 005250 → 업종코드 261
# [189/200] 종목 069260 → 업종코드 272
# [190/200] 종목 001430 → 업종코드 304
# [191/200] 종목 003620 → 업종코드 273
# [192/200] 종목 005420 → 업종코드 272
# [193/200] 종목 006650 → 업종코드 272
# [194/200] 종목 002710 → 업종코드 304
# [195/200] 종목 456040 → 업종코드 272
# [196/200] 종목 271940 → 업종코드 270
# [197/200] 종목 178920 → 업종코드 272
# [198/200] 종목 093370 → 업종코드 272
# [199/200] 종목 105630 → 업종코드 274
# [200/200] 종목 006110 → 업종코드 322
#
# 📦 최종 결과:
#        종목코드 업종코드  Cluster
# 0    005930  278        0
# 1    000660  278        0
# 2    042700  278        0
# 3    373220  283        1
# 4    006400  283        1
# ..      ...  ...      ...
# 195  137310  281       47
# 196  145720  281       47
# 197  009240  303       48
# 198  014820  311       49
# 199  008730  311       49
#
# [200 rows x 3 columns]

# %%
# 클러스터 개수와 종목 확인
df
# Out:
#        종목코드 업종코드  Cluster
# 0    005930  278        0
# 1    000660  278        0
# 2    042700  278        0
# 3    373220  283        1
# 4    006400  283        1
# ..      ...  ...      ...
# 195  137310  281       47
# 196  145720  281       47
# 197  009240  303       48
# 198  014820  311       49
# 199  008730  311       49
#
# [200 rows x 3 columns]

# %% [markdown]
# ### CSV로 저장

# %%
# 종목코드 앞에 0이오면 0이 사라진 후 저장되는 문제가 발생
# 그 이유는 종목코드를 int로 인지했기 때문. 그래서 문자열로 바꿔줌
# 000660 같은 경우, 660으로 저장되었었음

df['종목코드'] = df['종목코드'].astype(str)
df.to_csv("종목_업종_클러스터.csv", index=False)
